# %% [markdown]
# <a href="https://colab.research.google.com/github/Manojkumar-Siva/LGMVIP-Datascience-Task3/blob/main/LGM_iamge_To_sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image_path = 'bmw.jpg'
image = cv2.imread(image_path)

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
gray_image = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

# %%
inverted_gray_image = cv2.bitwise_not(gray_image)

# %%
blurred_inverted_image = cv2.GaussianBlur(inverted_gray_image, (51, 51), sigmaX=0, sigmaY=0)

# %%
pencil_sketch = cv2.divide(gray_image, 255 - blurred_inverted_image, scale=256)

# %%
plt.figure(figsize=(12, 8))

plt.subplot(1, 3, 1)
plt.imshow(image_rgb)
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(gray_image, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(pencil_sketch, cmap='gray')
plt.title('Pencil Sketch')
plt.axis('off')

plt.show()
